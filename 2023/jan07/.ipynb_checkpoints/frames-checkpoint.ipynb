# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
import pandas as pd

# %%
import random

# %%
import tqdm

# %%
import cv2
video = cv2.VideoCapture('../../../Downloads/Shrek.mp4')

# %%
total = int(video.get(cv2.CAP_PROP_FRAME_COUNT))

# %%
total
# Out:
# 450

# %%
fps = video.get(cv2.CAP_PROP_FPS)

# %%
video.set(cv2.CAP_PROP_POS_FRAMES, 449)
# Out:
# True

# %%
ret, frame = video.read()

# %%
plt.imshow(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))

# %%
frame.shape
# Out:
# (720, 1280, 3)

# %%
72/128
# Out:
# 0.5625

# %%
dim = (128,72)

# %%
plt.imshow(resized)

# %%
l = []

for i in tqdm.tqdm(range(total)):
    video.set(cv2.CAP_PROP_POS_FRAMES, i)

    ret, frame = video.read()

    resized = cv2.resize(
        cv2.cvtColor(frame, cv2.COLOR_BGR2RGB),
        dim
    )

    pxs = random.choices(
        pd.Series(
            resized.reshape((128*72,3)).tolist()
        ).apply(
            lambda x:','.join(map(str,x))
        ),
        k=5000
    )
    
    l.append(list(pxs))
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████| 450/450 [00:35<00:00, 12.67it/s]

# %%
import json
with open('frames.json', 'w') as f:
    json.dump(l, f)

# %%
random.choices(list(pxs),k=3)
# Out:
# ['17,13,45', '8,9,30', '4,2,14']

# %%
20*20
# Out:
# 400

# %%
l
# Out:
# [['8,9,30',
#   '0,0,10',
#   '1,1,11',
#   '7,8,27',
#   '9,10,31',
#   '1,1,9',
#   '21,22,43',
#   '7,6,23',
#   '20,21,42',
#   '3,3,15',
#   '8,6,26',
#   '2,2,12',
#   '6,5,20',
#   '8,7,24',
#   '4,2,14',
#   '10,8,30',
#   '4,4,16',
#   '9,7,27',
#   '9,7,29',
#   '2,2,14',
#   '3,3,13',
#   '23,21,43',
#   '19,20,43',
#   '7,6,21',
#   '4,3,18',
#   '6,6,18',
#   '24,22,42',
#   '8,9,28',
#   '0,0,8',
#   '7,8,29',
#   '22,20,44',
#   '2,0,8',
#   '24,22,44',
#   '18,19,42',
#   '25,23,43',
#   '23,21,45',
#   '5,3,15',
#   '2,2,10',
#   '19,20,41',
#   '21,22,45',
#   '12,12,38',
#   '9,10,33',
#   '21,22,41',
#   '20,21,44',
#   '6,7,26',
#   '22,23,44',
#   '0,0,6',
#   '21,19,43',
#   '20,18,42',
#   '22,20,42',
#   '6,5,22',
#   '23,24,45',
#   '19,19,45',
#   '25,23,45',
#   '11,13,38',
#   '8,11,29',
#   '11,12,33',
#   '13,13,39',
#   '28,26,48',
#   '15,15,41',
#   '11,12,35',
#   '18,18,44',
#   '13,13,41',
#   '11,9,31',
#   '15,16,39',
#   '16,16,42',
# ...

# %%
plt.imshow(resized)

# %%
img = cv2.imread('./S3.png', cv2.IMREAD_GRAYSCALE)

# %%
img.shape
# Out:
# (200, 200)

# %%
import json
with open('logo.json', 'w') as f:
    json.dump(img.tolist(), f)
